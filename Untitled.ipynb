# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows = 999
pd.options.display.max_columns =24
import datetime as dt
import colorsys
import pylab as pl


import plotly
from ipywidgets import widgets
from IPython.display import display
import plotly.graph_objs as go
from plotly.widgets import GraphWidget

# %%
import altair as alt
from vega_datasets import data


alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
df = pd.read_csv("./Dataset/massShooting2013-2018.csv", encoding = "ISO-8859-1")

# %%
df
# Out:
#            Date                 State                      City Or County  \
# 0     31-Dec-13              New York                            Brooklyn
# 1     28-Dec-13               Alabama                          Montgomery
# 2     26-Dec-13             Louisiana                             Slidell
# 3     26-Dec-13             Louisiana                            Lockport
# 4     25-Dec-13            New Jersey                           Irvington
# 5     25-Dec-13              New York                             Medford
# 6     22-Dec-13              Michigan                            Muskegon
# 7     21-Dec-13        North Carolina                              Shelby
# 8     21-Dec-13            New Jersey                             Trenton
# 9     15-Dec-13               Florida            Homestead (Florida City)
# 10    15-Dec-13                 Texas                         Channelview
# 11    14-Dec-13        North Carolina                         Statesville
# ...

# %%
data = """
{
  "$schema": "https://vega.github.io/schema/vega-lite/v2.json",
  "data": {
    "url": "https://raw.githubusercontent.com/dekuwin24/Data-Visualization/master/Dataset/massShooting2013-2018.csv",
    "format": { "type": "csv" }
  },
  "transform": [
    {"filter": "datum._vgsid_<=100"}
  ],
  "selection": {
    "search": {
      "bind": {
        "input": "input"
      },
      "empty": "none",
      "on": "mouseover",
      "fields": ["term"],
      "type": "single"
    },
    "highlight": {
      "type": "single",
      "on": "mouseover",
      "empty": "none"
    }
  },
  "mark": {
    "type": "bar",
    "stroke": "black"    
  },
  "encoding": {
    "color": {
      "condition": {
        "test": "(indexof(lower(datum.State), lower(search.State))>=0) || (highlight._vgsid_==datum._vgsid_)",
        "value": "SteelBlue"
      },
      "value": "LightGrey"
    },
    "y": {
      "field": "City Or County",
      "type": "ordinal",
      "sort": {"field": "total", "op": "argmax"}
    },
    "x": {
      "field": "# Injured",
      "type": "quantitative",
      "axis": {
      "title": "Restaurants"
      }
    }
  }
}
"""

# %%
alt.Chart.from_json(data)

# %%
t=df[['State', '# Killed', '# Injured']]
t
# Out:
#                      State  # Killed  # Injured
# 0                 New York         0          6
# 1                  Alabama         3          5
# 2                Louisiana         2          6
# 3                Louisiana         3          3
# 4               New Jersey         3          2
# 5                 New York         1          3
# 6                 Michigan         1          3
# 7           North Carolina         0          4
# 8               New Jersey         1          4
# 9                  Florida         1          3
# 10                   Texas         0          5
# 11          North Carolina         0          4
# 12                Delaware         0          4
# 13                  Kansas         4          0
# 14                 Florida         2          2
# 15                Michigan         0          5
# 16                 Georgia         0          4
# 17              California         0          4
# 18                 Indiana         0          4
# ...

# %%
t.rename(columns={'# Killed': 'killed','# Injured':'Injured' }, inplace=True)
# Out:
# /Users/dekuwinekogda/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(t.head())
# Out:
#         State  killed  Injured
# 0    New York       0        6
# 1     Alabama       3        5
# 2   Louisiana       2        6
# 3   Louisiana       3        3
# 4  New Jersey       3        2

# %%
alt.Chart(t).mark_point().encode(
    x='killed:Q',
    y='Injured:Q',
#     color=alt.Color('Acceleration:Q', bin=alt.Bin(maxbins=50))
)

# %%
# counties = alt.topo_feature('https://d3js.org/us-10m.v1.json', 'counties')
# states = alt.topo_feature('https://d3js.org/us-10m.v1.json', feature='states')
# capitals = 'https://raw.githubusercontent.com/dekuwin24/Data-Visualization/master/Dataset/massShooting2013-2018.csv'

states = alt.topo_feature('https://raw.githubusercontent.com/d3/d3-geo/master/test/data/us-10m.json', feature='states')
# airports = 'https://raw.githubusercontent.com/dekuwin24/Data-Visualization/master/Dataset/massShooting2013-2018.csv'
airports =t


background = alt.Chart(states).mark_geoshape(
    fill='lightgray',
    stroke='white',
    ).properties(
    width=800,
    height=500
    ).project('albersUsa')

points = alt.Chart(airports).mark_circle().encode(
    longitude='killed:Q',
    latitude='Injured:Q',
    size=alt.value(15),
    color=alt.value('#3377B3'),
    tooltip=['iata:N','name:N','state:N','killed:Q','Injured:Q'],
    )

chart = (background + points)
# chart.save('airports.html')
chart

# %%
# counties = alt.topo_feature('https://d3js.org/us-10m.v1.json', 'counties')
# states = alt.topo_feature('https://d3js.org/us-10m.v1.json', feature='states')
# capitals = 'https://raw.githubusercontent.com/dekuwin24/Data-Visualization/master/Dataset/massShooting2013-2018.csv'

states = alt.topo_feature('https://raw.githubusercontent.com/d3/d3-geo/master/test/data/us-10m.json', feature='states')
airports = t


# background = alt.Chart(states).mark_geoshape(
#     fill='lightgray',
#     stroke='white',
#     ).properties(
#     width=800,
#     height=500
#     ).project('albersUsa')

# points = alt.Chart(airports).mark_circle().encode(
#     longitude='longitude:Q',
#     latitude='latitude:Q',
#     size=alt.value(15),
#     color=alt.value('#3377B3'),
#     tooltip=['iata:N','name:N','city:N','state:N','latitude:Q','longitude:Q'],
#     )



alt.Chart(states).mark_geoshape().encode(
    color='# killed:Q'
).transform_lookup(
    lookup='State',
    from_=alt.LookupData(airports, 'State', ['killed'])
).project(
    type='albersUsa'
).properties(
    width=500,
    height=300
)
# chart = (background + points)
# chart.save('airports.html')
# chart

# %%
df_duplicates = df.drop_duplicates()
df_duplicates.shape
# Out:
# (1896, 6)

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Address    9
# dtype: int64

# %%
df.fillna(0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1896 entries, 0 to 1895
# Data columns (total 6 columns):
# Date              1896 non-null object
# State             1896 non-null object
# City Or County    1896 non-null object
# Address           1896 non-null object
# killed            1896 non-null int64
# Injured           1896 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 89.0+ KB

# %%
df['str_split'] = df.Date.str.split('-')
df['day'] = df.str_split.str.get(0)
df['months'] = df.str_split.str.get(1)
df['year'] = df.str_split.str.get(2)

df
# Out:
#            Date                 State                      City Or County  \
# 0     31-Dec-13              New York                            Brooklyn
# 1     28-Dec-13               Alabama                          Montgomery
# 2     26-Dec-13             Louisiana                             Slidell
# 3     26-Dec-13             Louisiana                            Lockport
# 4     25-Dec-13            New Jersey                           Irvington
# 5     25-Dec-13              New York                             Medford
# 6     22-Dec-13              Michigan                            Muskegon
# 7     21-Dec-13        North Carolina                              Shelby
# 8     21-Dec-13            New Jersey                             Trenton
# 9     15-Dec-13               Florida            Homestead (Florida City)
# 10    15-Dec-13                 Texas                         Channelview
# 11    14-Dec-13        North Carolina                         Statesville
# ...

# %%
df1= df[['year', 'State', 'City Or County','killed','Injured']]
df1.head()
# Out:
#   year       State City Or County  killed  Injured
# 0   13    New York       Brooklyn       0        6
# 1   13     Alabama     Montgomery       3        5
# 2   13   Louisiana        Slidell       2        6
# 3   13   Louisiana       Lockport       3        3
# 4   13  New Jersey      Irvington       3        2

# %%
df2=df1[df1['year'].astype(str).str.contains("18")]
df2.head()
df3=df2.groupby(['State'])["killed"].apply(lambda x : x.astype(int).sum()).to_frame('numb_killed').reset_index()
df3.head()
df3.to_csv('2018_masshooting_killed.csv')

# %%
sumInci=df1.groupby(['year','State','City Or County'])["killed"].apply(lambda x : x.astype(int).count()).to_frame('total_incident_count').reset_index()
sumInci.head()
# Out:
#   year    State   City Or County  total_incident_count
# 0   13  Alabama         Florence                     1
# 1   13  Alabama       Montgomery                     1
# 2   13  Arizona  Apache Junction                     1
# 3   13  Arizona         Avondale                     1
# 4   13  Arizona          Phoenix                     2

# %%
sumInci.rename(columns={'State': 'state' , 'City Or County':'city_or_county'}, inplace=True)

# %%
f2=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Alabama")]
f3=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Alaska")]
f4=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Arizona")]
f5=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Arkansas")]
f6=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("California")]
f7=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Colorado")]
f8=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Connecticut")]
f9=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Delaware")]
f10=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("District of Columbia")]
f11=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Florida")]
f12=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Georgia")]
f13=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Hawaii")]
f14=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Idaho")]
f15=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Illinois")]
f16=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Indiana")]
f17=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Iowa")]
f18=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Kansas")]
f19=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Kentucky")]
f20=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Louisiana")]
f21=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Maine")]
f22=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Maryland")]
f23=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Massachusetts")]
f24=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Michigan")]
f25=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Minnesota")]
f26=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Mississippi")]
f27=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Missouri")]
f28=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Montana")]
f29=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Nebraska")]
f30=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Nevada")]
f31=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("New Hampshire")]
f32=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("New Jersey")]
f33=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("New Mexico")]
f34=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("New York")]
f35=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("North Carolina")]
f36=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("North Dakota")]
f37=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Ohio")]
f38=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Oklahoma")]
f39=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Oregon")]
f40=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Pennsylvania")]
f41=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Rhode Island")]
f42=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("South Carolina")]
f43=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("South Dakota")]
f44=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Tennessee")]
f45=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Texas")]
f46=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Utah")]
f47=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Vermont")]
f48=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Virginia")]
f49=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Washington")]
f50=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("West Virginia")]
f51=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Wisconsin")]
f52=sumInci[sumInci['year'].astype(str).str.contains("18") & sumInci['state'].astype(str).str.contains("Wyoming")]

# %%
tr2 = go.Bar(x=list(f2["total_incident_count"]),
                y=list(f2["city_or_county"]),
                name="2018",
                text = list(f2["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr3 = go.Bar(x=list(f3["total_incident_count"]),
                y=list(f3["city_or_county"]),
                name="2018",
                text=list(f3["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr4 = go.Bar(x=list(f4["total_incident_count"]),
                y=list(f4["city_or_county"]),
                name="2018",
                text=list(f4["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr5 = go.Bar(x=list(f5["total_incident_count"]),
                y=list(f5["city_or_county"]),
                name="2018",
                text=list(f5["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr6 = go.Bar(x=list(f6["total_incident_count"]),
                y=list(f6["city_or_county"]),
                name="2018 ",
                text=list(f6["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr7 = go.Bar(x=list(f7["total_incident_count"]),
                y=list(f7["city_or_county"]),
                name="2018",
                text=list(f7["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr8 = go.Bar(x=list(f8["total_incident_count"]),
                y=list(f8["city_or_county"]),
                name="2018",
                text=list(f8["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr9 = go.Bar(x=list(f9["total_incident_count"]),
                y=list(f9["city_or_county"]),
                name="2018",
                text=list(f9["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr10 = go.Bar(x=list(f10["total_incident_count"]),
                y=list(f10["city_or_county"]),
                name="2018",
                text = list(f10["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr11 = go.Bar(x=list(f11["total_incident_count"]),
                y=list(f11["city_or_county"]),
                name="2018",
                text = list(f11["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )


tr12 = go.Bar(x=list(f12["total_incident_count"]),
                y=list(f12["city_or_county"]),
                name="2018",
                text = list(f12["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr13 = go.Bar(x=list(f13["total_incident_count"]),
                y=list(f13["city_or_county"]),
                name="2018",
                text = list(f13["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr14 = go.Bar(x=list(f14["total_incident_count"]),
                y=list(f14["city_or_county"]),
                name="2018",
                text = list(f14["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr15 = go.Bar(x=list(f15["total_incident_count"]),
                y=list(f15["city_or_county"]),
                name="2018",
                text = list(f15["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr16 = go.Bar(x=list(f16["total_incident_count"]),
                y=list(f16["city_or_county"]),
                name="2018",
                text = list(f16["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr17 = go.Bar(x=list(f17["total_incident_count"]),
                y=list(f17["city_or_county"]),
                name="2018",
                text = list(f17["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr18 = go.Bar(x=list(f18["total_incident_count"]),
                y=list(f18["city_or_county"]),
                name="2018",
                text = list(f18["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr19 = go.Bar(x=list(f19["total_incident_count"]),
                y=list(f19["city_or_county"]),
                name="2018",
                text = list(f19["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr20 = go.Bar(x=list(f20["total_incident_count"]),
                y=list(f20["city_or_county"]),
                name="2018",
                text = list(f20["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr21 = go.Bar(x=list(f21["total_incident_count"]),
                y=list(f21["city_or_county"]),
                name="2018",
                text = list(f21["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr22 = go.Bar(x=list(f22["total_incident_count"]),
                y=list(f22["city_or_county"]),
                name="2018",
                text = list(f22["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )


tr23 = go.Bar(x=list(f23["total_incident_count"]),
                y=list(f23["city_or_county"]),
                name="2018",
                text = list(f23["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr21 = go.Bar(x=list(f21["total_incident_count"]),
                y=list(f21["city_or_county"]),
                name="2018",
                text = list(f21["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )


tr24 = go.Bar(x=list(f24["total_incident_count"]),
                y=list(f24["city_or_county"]),
                name="2018",
                text = list(f24["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )


tr25 = go.Bar(x=list(f25["total_incident_count"]),
                y=list(f25["city_or_county"]),
                name="2018",
                text = list(f25["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr26 = go.Bar(x=list(f26["total_incident_count"]),
                y=list(f26["city_or_county"]),
                name="2018",
                text = list(f26["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr27 = go.Bar(x=list(f27["total_incident_count"]),
                y=list(f27["city_or_county"]),
                name="2018",
                text = list(f27["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr28 = go.Bar(x=list(f28["total_incident_count"]),
                y=list(f28["city_or_county"]),
                name="2018",
                text = list(f28["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr29 = go.Bar(x=list(f29["total_incident_count"]),
                y=list(f29["city_or_county"]),
                name="2018",
                text = list(f29["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )

tr30 = go.Bar(x=list(f30["total_incident_count"]),
                y=list(f30["city_or_county"]),
                name="2018",
                text = list(f30["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr31 = go.Bar(x=list(f31["total_incident_count"]),
                y=list(f31["city_or_county"]),
                name="2018",
                text = list(f31["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr32 = go.Bar(x=list(f32["total_incident_count"]),
                y=list(f32["city_or_county"]),
                name="2018",
                text = list(f32["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr33 = go.Bar(x=list(f33["total_incident_count"]),
                y=list(f33["city_or_county"]),
                name="2018",
                text = list(f33["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr34 = go.Bar(x=list(f34["total_incident_count"]),
                y=list(f34["city_or_county"]),
                name="2018",
                text = list(f34["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr35 = go.Bar(x=list(f35["total_incident_count"]),
                y=list(f35["city_or_county"]),
                name="2018",
                text = list(f35["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr36 = go.Bar(x=list(f36["total_incident_count"]),
                y=list(f36["city_or_county"]),
                name="2018",
                text = list(f36["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr37 = go.Bar(x=list(f37["total_incident_count"]),
                y=list(f37["city_or_county"]),
                name="2018",
                text = list(f37["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr38 = go.Bar(x=list(f38["total_incident_count"]),
                y=list(f38["city_or_county"]),
                name="2018",
                text = list(f38["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr39 = go.Bar(x=list(f39["total_incident_count"]),
                y=list(f39["city_or_county"]),
                name="2018",
                text = list(f39["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr40 = go.Bar(x=list(f40["total_incident_count"]),
                y=list(f40["city_or_county"]),
                name="2018",
                text = list(f40["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
                
tr41 = go.Bar(x=list(f41["total_incident_count"]),
                y=list(f41["city_or_county"]),
                name="2018",
                text = list(f41["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr42 = go.Bar(x=list(f42["total_incident_count"]),
                y=list(f42["city_or_county"]),
                name="2018",
                text = list(f42["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr43 = go.Bar(x=list(f43["total_incident_count"]),
                y=list(f43["city_or_county"]),
                name="2018",
                text = list(f43["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr44 = go.Bar(x=list(f44["total_incident_count"]),
                y=list(f44["city_or_county"]),
                name="2018",
                text = list(f44["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr45 = go.Bar(x=list(f45["total_incident_count"]),
                y=list(f45["city_or_county"]),
                name="2018",
                text = list(f45["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr46 = go.Bar(x=list(f46["total_incident_count"]),
                y=list(f46["city_or_county"]),
                name="2018",
                text = list(f46["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr47 = go.Bar(x=list(f47["total_incident_count"]),
                y=list(f47["city_or_county"]),
                name="2018",
                text = list(f47["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr48 = go.Bar(x=list(f48["total_incident_count"]),
                y=list(f48["city_or_county"]),
                name="2018",
                text = list(f48["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr49 = go.Bar(x=list(f49["total_incident_count"]),
                y=list(f49["city_or_county"]),
                name="2018",
                text = list(f49["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr50 = go.Bar(x=list(f50["total_incident_count"]),
                y=list(f50["city_or_county"]),
                name="2018",
                text = list(f50["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr51 = go.Bar(x=list(f51["total_incident_count"]),
                y=list(f51["city_or_county"]),
                name="2013",
                text = list(f51["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )
tr52 = go.Bar(x=list(f52["total_incident_count"]),
                y=list(f52["city_or_county"]),
                name="2018",
                text = list(f52["city_or_county"]),
                textposition="auto",
                hoverinfo="name",
                marker=dict(color="orange"),
              orientation='h'
                )





data = [tr2,tr3, tr4,tr5,tr6,tr7, tr8, tr9,
        tr10, tr11, tr12, tr13, tr14, tr15, tr16, tr17, tr18,tr19,
        tr20, tr21,tr22, tr23, tr24, tr25, tr26, tr27, tr28, tr29,
        tr30, tr31,tr32, tr33, tr34, tr35, tr36, tr37, tr38, tr39,
        tr40, tr41,tr42, tr43, tr44, tr45, tr46, tr47, tr48, tr49,
        tr50, tr51,tr52
       ]



updatemenus = list([
    dict(active=-1,
         buttons=list([   
            dict(label = "Alabama",
                 method = "update",
                 args = [{"visible": [True, False, False, False]},
                         {"title": "Alabama"}]),
            dict(label = "Alaska",
                 method = "update",
                 args = [{"visible": [False, True, False, False]},
                         {"title": "Alaska"}]),
             dict(label = "Arizona",
                 method = "update",
                 args = [{"visible": [False, False, True, False, False, False, False, False]},
                         {"title": "Arizona "}]),
             dict(label = "Arkansas",
                 method = "update",
                 args = [{"visible": [False, False, False, True, False, False, False, False]},
                         {"title": "Arkansas"}]),
             dict(label = "California",
                 method = "update",
                 args = [{"visible": [False, False, False, False, True, False, False, False]},
                         {"title": "California"}]),
             dict(label = "Colorado",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, True, False, False]},
                         {"title": "Colorado"}]),
             dict(label = "Connecticut",
                 method = "update",
                 args = [{"visible":[False, False, False, False, False, False, True, False, False]},
                         {"title": "Connecticut"}]),
             dict(label = "Delaware",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, True, False]},
                         {"title": "Delaware"}]), 
             dict(label = "District of Columbia",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, True, False]},
                         {"title": "District of Columbia"}]),
             dict(label = "Florida",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Florida "}]),
             dict(label = "Georgia",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Georgia"}]),
             dict(label = "Hawaii",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, True,False]},
                         {"title": "Hawaii "}]),
             dict(label = "Idaho",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Idaho"}]),
             dict(label = "Illinois",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False,False, False, False, False, False, False, True, False]},
                         {"title": "Illinois"}]),
             dict(label = "Idiana",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Idiana "}]),
             dict(label = "Iowa",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Iowa"}]),
             dict(label = "Kansas",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Kansas "}]),
             dict(label = "Kentucky",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Kentucky "}]),
              dict(label = "Louisiana",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Louisiana"}]),
             dict(label = "Maine",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Maine"}]),
             dict(label = "Maryland",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Maryland"}]),
             dict(label = "Massachusetts",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Massachusetts"}]),
             dict(label = "Michigan",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Michigan"}]),
             dict(label = "Minnesota",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Minnesota "}]),
             dict(label = "Mississippi",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Mississippi "}]),
             dict(label = "Missouri",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Missouri "}]),
             dict(label = "Montana",
                 method = "update",
                args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Montana "}]),
            dict(label = "Nebraska",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Nebraska "}]),
             dict(label = "Nevada",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Nevada "}]),
            dict(label = "New Hampshire",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "New Hampshire "}]), 
           dict(label = "New Jersey",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "New Jersey "}]),
           dict(label = "New Mexico",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "New Mexico "}]),
              dict(label = "New York",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "New York "}]),
           dict(label = "North Carolina",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "North Carolina "}]),
             dict(label = "North Dekota",
                 method = "update",
                args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "North Dekota "}]),
           dict(label = "Ohio",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Ohio "}]),
           dict(label = "Oklahoma",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,  True, False]},
                         {"title": "Oklahoma "}]),
            dict(label = "Oregon",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},                         
                         {"title": "Oregon "}]),
            dict(label = "Pennsylvania",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False,False,  False, True, False]},
                         {"title": "Pennsylvania "}]),
            dict(label = "Rhode Islande",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Rhode Island"}]),
            dict(label = "South Carolina",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "South Carolina "}]),
            dict(label = "South Dekota",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "South Dekota  "}]),
            dict(label = "Tennessee",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Tennessee "}]),
            dict(label = "Texas",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Texas "}]),
            dict(label = "Utah",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Utah "}]),
            dict(label = "Vermont",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Vermont "}]),
            dict(label = "Virginia",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Virginia "}]),
            dict(label = "Washinton",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Washinton "}]),
            dict(label = "West Virginia",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "West Virginia "}]),
            dict(label = "Wesconston",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Wesconston "}]),
            dict(label = "Wyoming",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                         {"title": "Wyoming "}]),
            dict(label = "All",
                 method = "update",
                 args = [{"visible": [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]},
                         {"title": "All"}]),
            dict(label = "Reset",
                 method = "update",
                 args = [{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                         {"title": "Reset"}])
        ]),
    )
])

# Set layout => the whole graph layout
layout = dict(title="Gun Death ",
              showlegend=False,
              xaxis=dict(title="total_incident_count"),
              yaxis=dict(title="city_or_county"),
              updatemenus=updatemenus)

# creating the fig
fig = dict(data=data, layout=layout)
# Plot the plotly plot => It will open as a html file 
plotly.offline.plot(fig, filename="Gun_Death.html")
# Out:
# 'file:///Users/dekuwinekogda/Desktop/DS/Data-Visualization/Gun_Death.html'

# %%
# !conda install plotly
# !conda install geopandas
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dekuwinekogda/anaconda3
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     plotly-3.4.2               |   py36h28b3542_0        27.9 MB
#
# The following packages will be UPDATED:
#
#     plotly: 3.4.2-py36_0 plotly --> 3.4.2-py36h28b3542_0
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dekuwinekogda/anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.14.12              |       he60d9cb_2         1.2 MB
# ...

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-9063a9f0e032> in <module>()
# ----> 1 y
#
# NameError: name 'y' is not defined
